# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('operations_cleaned.csv')
df
# Out:
#        Mission ID Mission Date Theater of Operations Country Air Force  \
# 0             184    7/29/1944                   ETO     USA      9 AF
# 1             185    7/29/1944                   ETO     USA      9 AF
# 2             217    2/16/1945                   ETO     USA     15 AF
# 3             218    2/16/1945                   ETO     USA     15 AF
# 4             219    2/16/1945                   ETO     USA     15 AF
# ...           ...          ...                   ...     ...       ...
# 18175      178634    7/28/1944                   MTO     USA      9 AF
# 18176      178635    7/28/1944                   MTO     USA      9 AF
# 18177      178636    7/28/1944                   MTO     USA      9 AF
# 18178      178637    7/28/1944                   MTO     USA      9 AF
# 18179      178638    7/28/1944                   MTO     USA      9 AF
#
#       Aircraft Series  Target ID Target Country Target City  \
# 0                 B17    19196.0        GERMANY  HILDESHEIM
# 1                 B17    19196.0        GERMANY  HILDESHEIM
# 2                 B24    17665.0        AUSTRIA        HALL
# 3                 B24    20563.0        AUSTRIA   INNSBRUCK
# 4                 B24    20563.0        AUSTRIA   INNSBRUCK
# ...               ...        ...            ...         ...
# 18175             B24    34105.0        ROMANIA     PLOESTI
# 18176             B24    34105.0        ROMANIA     PLOESTI
# 18177             B24    34105.0        ROMANIA     PLOESTI
# 18178             B24    34105.0        ROMANIA     PLOESTI
# 18179             B24    34105.0        ROMANIA     PLOESTI
#
#              Target Type  ... Target Priority  Target Latitude  \
# 0       MARSHALLING YARD  ...               2            52.15
# 1       MARSHALLING YARD  ...               2            52.15
# 2      MARSHALLING YARDS  ...               2            47.28
# 3      MARSHALLING YARDS  ...               3            47.27
# 4      MARSHALLING YARDS  ...               3            47.27
# ...                  ...  ...             ...              ...
# 18175       OIL REFINERY  ...               1            44.93
# 18176       OIL REFINERY  ...               1            44.93
# 18177       OIL REFINERY  ...               1            44.93
# 18178       OIL REFINERY  ...               1            44.93
# 18179       OIL REFINERY  ...               1            44.93
#
#        Target Longitude  Altitude (Hundreds of Feet)  Airborne Aircraft  \
# 0                  9.97                        265.0               17.0
# 1                  9.97                        253.0                8.0
# 2                 11.50                        250.0               23.0
# 3                 11.38                        250.0                1.0
# 4                 11.38                        248.0                6.0
# ...                 ...                          ...                ...
# 18175             26.05                        223.0               17.0
# 18176             26.05                        220.0               31.0
# 18177             26.05                        220.0               31.0
# 18178             26.05                        218.0               27.0
# 18179             26.05                        218.0               27.0
#
#        Attacking Aircraft  Bombing Aircraft  High Explosives Weight (Tons)  \
# 0                    17.0              17.0                           42.0
# 1                     8.0               8.0                           20.0
# 2                    23.0              23.0                           44.0
# 3                     1.0               1.0                            2.0
# 4                     6.0               6.0                           12.0
# ...                   ...               ...                            ...
# 18175                17.0              17.0                           41.0
# 18176                31.0              31.0                           76.0
# 18177                31.0              31.0                           76.0
# 18178                27.0              27.0                           65.0
# 18179                27.0              27.0                           65.0
#
#        Total Weight (Tons)  Source ID
# 0                     42.0   170082.0
# 1                     20.0   170083.0
# 2                     44.0   186045.0
# 3                      2.0   186048.0
# 4                     12.0   186047.0
# ...                    ...        ...
# 18175                 41.0   169993.0
# 18176                 76.0   106301.0
# 18177                 76.0   169982.0
# 18178                 65.0   106307.0
# 18179                 65.0   169988.0
#
# [18180 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Mission ID                       0
# Mission Date                     0
# Theater of Operations            0
# Country                          0
# Air Force                        0
# Aircraft Series                  0
# Target ID                        0
# Target Country                   0
# Target City                      0
# Target Type                      0
# Target Industry                  0
# Target Priority                  0
# Target Latitude                  0
# Target Longitude                 0
# Altitude (Hundreds of Feet)      0
# Airborne Aircraft                0
# Attacking Aircraft               0
# Bombing Aircraft                 0
# High Explosives Weight (Tons)    0
# Total Weight (Tons)              0
# Source ID                        0
# dtype: int64

# %%
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
num_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()
print("Categorical columns:", cat_cols)
print("Numeric columns:", num_cols)

for col in cat_cols:
    print(f"\nValues count for '{col}':")
    print(df[col].value_counts())

for num in num_cols:
    print(f"\nValues count for '{col}':")
    print (df[num].value_counts())
# Out:
# Categorical columns: ['Mission Date', 'Theater of Operations', 'Country', 'Air Force', 'Aircraft Series', 'Target Country', 'Target City', 'Target Type', 'Target Industry']
# Numeric columns: ['Mission ID', 'Target ID', 'Target Priority', 'Target Latitude', 'Target Longitude', 'Altitude (Hundreds of Feet)', 'Airborne Aircraft', 'Attacking Aircraft', 'Bombing Aircraft', 'High Explosives Weight (Tons)', 'Total Weight (Tons)', 'Source ID']
#
# Values count for 'Mission Date':
# Mission Date
# 7/25/1944     233
# 8/24/1944     183
# 4/17/1945     161
# 10-06-1944    159
# 3/28/1945     154
#              ...
# 10/15/1942      1
# 1/14/1945       1
# 11/22/1942      1
# 12-06-1942      1
# 7/25/1942       1
# Name: count, Length: 629, dtype: int64
#
# Values count for 'Theater of Operations':
# Theater of Operations
# ETO    10511
# MTO     7669
# Name: count, dtype: int64
#
# Values count for 'Country':
# Country
# USA              17708
# GREAT BRITAIN      472
# Name: count, dtype: int64
#
# Values count for 'Air Force':
# Air Force
# 12 AF    6227
# 15 AF    5535
# 8 AF     3358
# 9 AF     2323
# RAF       472
# 1 TAC     265
# Name: count, dtype: int64
#
# Values count for 'Aircraft Series':
# Aircraft Series
# B17     5607
# B24     4328
# B25     1938
# A20     1738
# GB17    1408
# B26      935
# A26      726
# OB24     439
# HVY      434
# GB24     287
# OB17     208
# 0B24      72
# 0B17      28
# MED       28
# LGT        4
# Name: count, dtype: int64
#
# Values count for 'Target Country':
# Target Country
# GERMANY           6120
# ITALY             5978
# AUSTRIA           2323
# FRANCE            1345
# ROMANIA            593
# CZECHOSLOVAKIA     528
# HUNGARY            510
# YUGOSLAVIA         441
# POLAND             100
# GREECE              81
# BULGARIA            56
# TUNISIA             32
# PANTELLARIA         30
# BELGIUM             18
# ALBANIA             12
# DENMARK              8
# CORSICA              4
# LUXEMBOURG           1
# Name: count, dtype: int64
#
# Values count for 'Target City':
# Target City
# VIENNA              707
# MUNICH              629
# BERLIN              476
# PLOESTI             331
# 45 00 N 010 40 E    311
#                    ...
# POJNICA               1
# HUNFELD               1
# LE CLIPON             1
# KELLMUNZ              1
# FLORINA               1
# Name: count, Length: 1140, dtype: int64
#
# Values count for 'Target Type':
# Target Type
# CITY AREA                 1387
# MARSHALLING YARD          1384
# AIRDROME                  1020
# BRIDGE                     978
# MARSHALLING YARDS          905
#                           ...
# AIRCRAFT ASSEMBLY PLAN       1
# STEEL ARM WKS OF FRIED       1
# BENZOL PLANT                 1
# RR YDS                       1
# RAIL CUTTING                 1
# Name: count, Length: 464, dtype: int64
#
# Values count for 'Target Industry':
# Target Industry
# "RR INSTALLATIONS,  TRACKS,  MARSHALLING YARDS,  AND STATIONS"                                                               3217
# BRIDGES                                                                                                                      2366
# CITIES TOWNS AND URBAN AREAS                                                                                                 1573
# OIL REFINERIES                                                                                                               1495
# AIR FIELDS AND AIRDROMES                                                                                                     1436
# TACTICAL TARGETS: (UNIDENTIFIED OR NOT LISTED BELOW)                                                                          855
# SUPPLY DUMPS AND WAREHOUSES                                                                                                   854
# WATERWAYS AND BOATS                                                                                                           668
# SYNTHETIC OIL REFINERIES                                                                                                      620
# GUN EMPLACEMENTS                                                                                                              555
# AIRCRAFT FACTORIES AND ASSEMBLY PLANTS                                                                                        516
# ARMAMENT AND ORDNANCE PLANTS                                                                                                  499
# TANK FACTORIES                                                                                                                461
# UNIDENTIFIED TARGETS                                                                                                          460
# TROOP CONCENTRATIONS                                                                                                          377
# VEHICLE MFG. PLANTS                                                                                                           266
# ENGINE PLANTS                                                                                                                 249
# PORTS AND HARBORS                                                                                                             232
# A/C COMPONENT PLANTS                                                                                                          187
# OIL STORAGE FACILITIES AND OTHER OIL INSTALLATIONS                                                                            173
# HIGHWAYS AND VEHICLES                                                                                                         161
# V-WEAPON FACTORIES                                                                                                            127
# EXPLOSIVES MFG. PLANTS                                                                                                        108
# MANUFACTURING INSTALLATIONS (NOT SPECIFICALLY IDENTIFIED BELOW FROM CLASS 11 THROUGH 59)                                      103
# V - WEAPON LAUNCHING SITES                                                                                                     98
# NAVAL INSTALLATIONS                                                                                                            59
# R.R. MANUFACTURING WORKS AND ROUNDHOUSES                                                                                       52
# CHEMICAL PLANTS                                                                                                                52
# SUBMARINE PENS AND YARDS                                                                                                       42
# "IRON AND STEEL PRODUCTION FACILITIES,  BLAST FURNACES,  BOILER SHOPS,  FORGES,  FOUNDRIES, STEEL WORKS,  ROLLING-MILLS "      37
# SHIP BUILDING                                                                                                                  36
# RADIO & RADAR INSTALLATIONS                                                                                                    36
# SHIPS                                                                                                                          34
# "PUBLIC UTILITIES - ELECTRIC LIGHT AND POWER COMPANIES,  GAS COMPANIES, TELEPHONE COMPANIES,  WATER COMPANIES.  "              34
# BEARINGS MFG. PLANTS                                                                                                           33
# MOVING TRAINS & ROLLING STOCK                                                                                                  19
# TUNNELS                                                                                                                        17
# MACHINERY & EQUIPMENT MFG. PLANTS                                                                                              16
# TRANSPORTATION FACILITIES (NOT SPECIFICALLY IDENTIFIED BELOW)                                                                  13
# SYNTHETIC RUBBER MFG.                                                                                                          13
# RUBBER AND TIRE MANUFACTURING FACILITIES                                                                                       12
# NATURAL OIL REFINERIES                                                                                                         12
# "TUGS,  BARGES,  AND SAMPANS  "                                                                                                 6
# DIRECT COOPERATION WITH GROUND FORCES                                                                                           1
# Name: count, dtype: int64
#
# Values count for 'Target Industry':
# Mission ID
# 184       1
# 111515    1
# 111659    1
# 111658    1
# 111520    1
#          ..
# 52494     1
# 52495     1
# 52496     1
# 52536     1
# 178638    1
# Name: count, Length: 18180, dtype: int64
#
# Values count for 'Target Industry':
# Target ID
# 45241.0    707
# 29563.0    629
# 3735.0     476
# 34105.0    331
# 90703.0    311
#           ...
# 5154.0       1
# 8437.0       1
# 34486.0      1
# 21605.0      1
# 14101.0      1
# Name: count, Length: 1137, dtype: int64
#
# Values count for 'Target Industry':
# Target Priority
# 1    14588
# 2     2368
# 3      844
# 4      326
# 5       21
# 6       15
# 7        8
# 9        6
# 8        3
# 0        1
# Name: count, dtype: int64
#
# Values count for 'Target Industry':
# Target Latitude
# 48.20    738
# 48.13    686
# 45.00    684
# 52.53    476
# 44.67    436
#         ...
# 50.57      1
# 46.73      1
# 46.17      1
# 40.62      1
# 40.78      1
# Name: count, Length: 584, dtype: int64
#
# Values count for 'Target Industry':
# Target Longitude
# 11.58    718
# 16.37    714
# 11.00    482
# 13.42    478
# 14.30    438
#         ...
# 6.35       1
# 7.92       1
# 0.27       1
# 4.20       1
# 21.42      1
# Name: count, Length: 642, dtype: int64
#
# Values count for 'Target Industry':
# Altitude (Hundreds of Feet)
# 250.0    682
# 230.0    665
# 220.0    640
# 240.0    561
# 100.0    547
#         ...
# 16.0       1
# 148.0      1
# 323.0      1
# 306.0      1
# 161.0      1
# Name: count, Length: 275, dtype: int64
#
# Values count for 'Target Industry':
# Airborne Aircraft
# 12.0     2498
# 1.0      1850
# 11.0     1159
# 18.0      930
# 13.0      880
#          ...
# 224.0       1
# 332.0       1
# 68.0        1
# 71.0        1
# 313.0       1
# Name: count, Length: 105, dtype: int64
#
# Values count for 'Target Industry':
# Attacking Aircraft
# 12.0     2498
# 1.0      1850
# 11.0     1159
# 18.0      930
# 13.0      880
#          ...
# 224.0       1
# 332.0       1
# 68.0        1
# 71.0        1
# 313.0       1
# Name: count, Length: 105, dtype: int64
#
# Values count for 'Target Industry':
# Bombing Aircraft
# 12.0     2498
# 1.0      1850
# 11.0     1159
# 18.0      930
# 13.0      880
#          ...
# 224.0       1
# 332.0       1
# 68.0        1
# 71.0        1
# 313.0       1
# Name: count, Length: 105, dtype: int64
#
# Values count for 'Target Industry':
# High Explosives Weight (Tons)
# 1.0      1590
# 2.0       885
# 30.0      725
# 36.0      638
# 33.0      509
#          ...
# 224.0       1
# 401.0       1
# 462.0       1
# 456.0       1
# 359.0       1
# Name: count, Length: 282, dtype: int64
#
# Values count for 'Target Industry':
# Total Weight (Tons)
# 1.0      1035
# 30.0      846
# 2.0       822
# 36.0      731
# 33.0      581
#          ...
# 345.0       1
# 679.0       1
# 722.0       1
# 389.0       1
# 434.0       1
# Name: count, Length: 340, dtype: int64
#
# Values count for 'Target Industry':
# Source ID
# 170082.0    1
# 224840.0    1
# 101760.0    1
# 165715.0    1
# 224844.0    1
#            ..
# 219830.0    1
# 120464.0    1
# 219826.0    1
# 98892.0     1
# 169988.0    1
# Name: count, Length: 18180, dtype: int64

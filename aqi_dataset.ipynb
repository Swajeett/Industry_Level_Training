# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('aqi_india.csv')
df
# Out:
#                  city           state  latitude  longitude          datetime  \
# 0            agartala         tripura   23.8315    91.2868  05-08-2022 00:00
# 1            agartala         tripura   23.8315    91.2868  05-08-2022 01:00
# 2            agartala         tripura   23.8315    91.2868  05-08-2022 02:00
# 3            agartala         tripura   23.8315    91.2868  05-08-2022 03:00
# 4            agartala         tripura   23.8315    91.2868  05-08-2022 04:00
# ...               ...             ...       ...        ...               ...
# 842155  visakhapatnam  andhra pradesh   17.6868    83.2185  26-11-2025 19:00
# 842156  visakhapatnam  andhra pradesh   17.6868    83.2185  26-11-2025 20:00
# 842157  visakhapatnam  andhra pradesh   17.6868    83.2185  26-11-2025 21:00
# 842158  visakhapatnam  andhra pradesh   17.6868    83.2185  26-11-2025 22:00
# 842159  visakhapatnam  andhra pradesh   17.6868    83.2185  26-11-2025 23:00
#
# ...

# %%
df.head()
df.tail()
df.info()
df.shape
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842160 entries, 0 to 842159
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   city                 842160 non-null  object
#  1   state                842160 non-null  object
#  2   latitude             842160 non-null  float64
#  3   longitude            842160 non-null  float64
#  4   datetime             842160 non-null  object
#  5   month                842160 non-null  int64
#  6   day_name             842160 non-null  object
#  7   is_weekend           842160 non-null  bool
#  8   season               842160 non-null  object
#  9   time_of_day          842160 non-null  object
#  10  humidity_percent     842160 non-null  int64
#  11  dew_point_c          842160 non-null  float64
#  12  wind_gusts_kmh       842160 non-null  float64
#  13  precipitation_mm     842160 non-null  float64
#  14  is_raining           842160 non-null  bool
# ...

# %%
df.describe().T
# Out:
#                         count         mean         std       min        25%  \
# latitude             842160.0    23.129041    5.543478    8.5241    20.2961
# longitude            842160.0    82.769207    6.937205   72.5714    77.1734
# month                842160.0     6.801653    3.411504    1.0000     4.0000
# humidity_percent     842160.0    71.324796   21.362100    3.0000    58.0000
# dew_point_c          842160.0    17.160777    7.020427  -11.5000    12.1000
# wind_gusts_kmh       842160.0    19.270394    9.921461    3.2000    11.5000
# precipitation_mm     842160.0     0.197799    0.915802    0.0000     0.0000
# pressure_msl_hpa     842160.0  1009.489776    5.698795  979.4000  1005.4000
# cloud_cover_percent  842160.0    50.501230   43.413480    0.0000     2.0000
# pm2_5_ugm3           842160.0    34.549825   29.652013    1.9000    14.7000
# pm10_ugm3            842160.0    54.014723   54.231554    2.3000    21.5000
# ...

# %%
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
num_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()
print("Categorical columns:", cat_cols)
print("Numeric columns:", num_cols)

for col in cat_cols:
    print(f"\nValues count for '{col}':")
    print(df[col].value_counts())
# Out:
# Categorical columns: ['city', 'state', 'datetime', 'day_name', 'season', 'time_of_day', 'aqi_category', 'pm25_category_india']
# Numeric columns: ['latitude', 'longitude', 'month', 'humidity_percent', 'dew_point_c', 'wind_gusts_kmh', 'precipitation_mm', 'pressure_msl_hpa', 'cloud_cover_percent', 'pm2_5_ugm3', 'pm10_ugm3', 'co_ugm3', 'no2_ugm3', 'so2_ugm3', 'o3_ugm3', 'dust_ugm3', 'aod', 'us_aqi']
#
# Values count for 'city':
# city
# agartala              29040
# itanagar              29040
# thiruvananthapuram    29040
# shimla                29040
# shillong              29040
# ranchi                29040
# raipur                29040
# patna                 29040
# panaji                29040
# mumbai                29040
# lucknow               29040
# kolkata               29040
# kohima                29040
# jaipur                29040
# imphal                29040
# ahmedabad             29040
# hyderabad             29040
# guwahati              29040
# ...

# %%
# Check null Values
df.isnull().sum()
# Out:
# city                   0
# state                  0
# latitude               0
# longitude              0
# datetime               0
# month                  0
# day_name               0
# is_weekend             0
# season                 0
# time_of_day            0
# humidity_percent       0
# dew_point_c            0
# wind_gusts_kmh         0
# precipitation_mm       0
# is_raining             0
# heavy_rain             0
# pressure_msl_hpa       0
# cloud_cover_percent    0
# pm2_5_ugm3             0
# pm10_ugm3              0
# co_ugm3                0
# no2_ugm3               0
# so2_ugm3               0
# o3_ugm3                0
# dust_ugm3              0
# aod                    0
# us_aqi                 0
# aqi_category           0
# pm25_category_india    2
# festival_period        0
# crop_burning_season    0
# dtype: int64

# %%
df['pm25_category_india'] = df['pm25_category_india'].fillna('NA')
df['pm25_category_india'].isnull().sum()
print(df.isnull().sum())
df.to_csv("aqi_india_Cleaned.csv",index=False)
# Out:
# city                   0
# state                  0
# latitude               0
# longitude              0
# datetime               0
# month                  0
# day_name               0
# is_weekend             0
# season                 0
# time_of_day            0
# humidity_percent       0
# dew_point_c            0
# wind_gusts_kmh         0
# precipitation_mm       0
# is_raining             0
# heavy_rain             0
# pressure_msl_hpa       0
# cloud_cover_percent    0
# pm2_5_ugm3             0
# pm10_ugm3              0
# co_ugm3                0
# no2_ugm3               0
# so2_ugm3               0
# o3_ugm3                0
# dust_ugm3              0
# aod                    0
# us_aqi                 0
# aqi_category           0
# pm25_category_india    0
# festival_period        0
# crop_burning_season    0
# dtype: int64

# %%
# Check duplicate values
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# Basic sanity
# city, latitude, longitude
print("City from:", df['city'].min(), "to", df['city'].max())
print("Latitude Range:", df['latitude'].min(), "to", df['latitude'].max())
print("Longitude Range:", df['longitude'].min(), "to", df['longitude'].max())
# Out:
# City from: agartala to visakhapatnam
# Latitude Range: 8.5241 to 31.1048
# Longitude Range: 72.5714 to 94.1086
